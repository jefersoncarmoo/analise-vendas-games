# %% [markdown]
# # Lendo e Tratando os dados

# %%
#Importando Bibliotecas
#Bibliotecas para modelagem e matrizes
import numpy as np
import pandas as pd

#Biliotecas para análises gráficas
import matplotlib.pyplot as plt
import seaborn as sns

#Biblioteca para ignorar avisos
import warnings

#Desabilitanto avisos
warnings.filterwarnings('ignore')

# %%
Base_Dados = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/Projetos Práticos - Curso DataV/ Projeto Análise Mercado de Games/Video_Games_Sales_as_at_22_Dec_2016.csv')

Base_Dados.head()
# Out:
#                        Name Platform  Year_of_Release         Genre Publisher  \
# 0                Wii Sports      Wii           2006.0        Sports  Nintendo
# 1         Super Mario Bros.      NES           1985.0      Platform  Nintendo
# 2            Mario Kart Wii      Wii           2008.0        Racing  Nintendo
# 3         Wii Sports Resort      Wii           2009.0        Sports  Nintendo
# 4  Pokemon Red/Pokemon Blue       GB           1996.0  Role-Playing  Nintendo
#
#    NA_Sales  EU_Sales  JP_Sales  Other_Sales  Global_Sales  Critic_Score  \
# 0     41.36     28.96      3.77         8.45         82.53          76.0
# 1     29.08      3.58      6.81         0.77         40.24           NaN
# 2     15.68     12.76      3.79         3.29         35.52          82.0
# 3     15.61     10.93      3.28         2.95         32.77          80.0
# 4     11.27      8.89     10.22         1.00         31.37           NaN
#
#    Critic_Count  User_Score  User_Count Developer Rating
# 0          51.0         8.0       322.0  Nintendo      E
# 1           NaN         NaN         NaN       NaN    NaN
# 2          73.0         8.3       709.0  Nintendo      E
# 3          73.0         8.0       192.0  Nintendo      E
# 4           NaN         NaN         NaN       NaN    NaN

# %%
#Obtendo a dimensão da base de dados (Linhas e colunas)
Base_Dados.shape
# Out:
# (16719, 16)

# %%
#Analisando campos nulos na base de dados
Base_Dados.isnull().sum()
# Out:
# Name                  2
# Platform              0
# Year_of_Release     269
# Genre                 2
# Publisher            54
# NA_Sales              0
# EU_Sales              0
# JP_Sales              0
# Other_Sales           0
# Global_Sales          0
# Critic_Score       8582
# Critic_Count       8582
# User_Score         9129
# User_Count         9129
# Developer          6623
# Rating             6769
# dtype: int64

# %%
#Visualização gráfica dos campos nulos
plt.figure(figsize=(15,5))
sns.heatmap(Base_Dados.isnull(), cbar=False, cmap='viridis');

# %%
#Removendo colunas
Base_Dados.drop(['Critic_Score', 'Critic_Count', 'User_Score', 'User_Count', 'Developer',	'Rating'], axis=1, inplace=True)

# %%
Base_Dados.head()
# Out:
#                        Name Platform  Year_of_Release         Genre Publisher  \
# 0                Wii Sports      Wii           2006.0        Sports  Nintendo
# 1         Super Mario Bros.      NES           1985.0      Platform  Nintendo
# 2            Mario Kart Wii      Wii           2008.0        Racing  Nintendo
# 3         Wii Sports Resort      Wii           2009.0        Sports  Nintendo
# 4  Pokemon Red/Pokemon Blue       GB           1996.0  Role-Playing  Nintendo
#
#    NA_Sales  EU_Sales  JP_Sales  Other_Sales  Global_Sales
# 0     41.36     28.96      3.77         8.45         82.53
# 1     29.08      3.58      6.81         0.77         40.24
# 2     15.68     12.76      3.79         3.29         35.52
# 3     15.61     10.93      3.28         2.95         32.77
# 4     11.27      8.89     10.22         1.00         31.37

# %%
#Renomeando colunas
Base_Dados.rename( columns={
    'Name' : 'Nome',
    'Platform' : 'Plataforma',
    'Year_of_Release' : 'Ano_Lancamento',
    'Genre' : 'Genero',
    'Publisher' : 'Publicadora',
    'NA_Sales': 'Vendas_America_Norte',
    'EU_Sales': 'Vendas_Europa',
    'JP_Sales': 'Vendas_Japao',
    'Other_Sales': 'Vendas_Outras_Regioes',
    'Global_Sales': 'Vendas_Global'
}, inplace=True )
Base_Dados.head()
# Out:
#                        Nome Plataforma  Ano_Lancamento        Genero  \
# 0                Wii Sports        Wii          2006.0        Sports
# 1         Super Mario Bros.        NES          1985.0      Platform
# 2            Mario Kart Wii        Wii          2008.0        Racing
# 3         Wii Sports Resort        Wii          2009.0        Sports
# 4  Pokemon Red/Pokemon Blue         GB          1996.0  Role-Playing
#
#   Publicadora  Vendas_America_Norte  Vendas_Europa  Vendas_Japao  \
# 0    Nintendo                 41.36          28.96          3.77
# 1    Nintendo                 29.08           3.58          6.81
# 2    Nintendo                 15.68          12.76          3.79
# 3    Nintendo                 15.61          10.93          3.28
# 4    Nintendo                 11.27           8.89         10.22
#
#    Vendas_Outras_Regioes  Vendas_Global
# 0                   8.45          82.53
# 1                   0.77          40.24
# 2                   3.29          35.52
# 3                   2.95          32.77
# 4                   1.00          31.37

# %%
#Removendo as linhas com valores nulos da coluna Ano_Lancamento
Base_Dados.dropna(subset=['Ano_Lancamento'], inplace=True)

# %% [markdown]
# # Análise Gráfica

# %%
#Criando uma paleta de cores para os gráficos
Paleta_Cores = sns.color_palette('husl', 10)
Paleta_Cores
# Out:
# [(0.9677975592919913, 0.44127456009157356, 0.5358103155058701),
#  (0.8616090647292522, 0.536495730113334, 0.19548899031476086),
#  (0.6804189127793346, 0.6151497514677574, 0.19405452111445337),
#  (0.46810256823426105, 0.6699492535792404, 0.1928958739904499),
#  (0.20125317221201128, 0.6907920815379025, 0.47966761189275336),
#  (0.21044753832183283, 0.6773105080456748, 0.6433941168468681),
#  (0.2197995660828324, 0.6625157876850336, 0.7732093159317209),
#  (0.433280341176423, 0.6065273407962815, 0.9585467098271748),
#  (0.8004936186423958, 0.47703363533737203, 0.9579547196007522),
#  (0.962272393509669, 0.3976451968965351, 0.8008274363432775)]

# %%
#Tamanho da Imagem
plt.figure(figsize=(15,5))

#Título
plt.title('Vendas Globais por Gênero (1980 a 2020)', loc='left', fontsize=14)

#Gráfico de barras usando os vendas globais por gênero
#ci=None: Remove o intervalo de confiança (tracinho preto em cada barra)
#estimator=sum: Especifica que os valores de "Global" devem ser somados para cada ano.
sns.barplot(data=Base_Dados, x='Genero', y='Vendas_Global', ci=None, color=Paleta_Cores[0], estimator=sum)

#Label
plt.ylabel('Quantidade de vendas (mi)');

# %%
#Tamanho da Imagem
plt.figure(figsize=(15,5))

#Título
plt.title('Vendas Globais por Plataforma (1980 a 2020)', loc='left', fontsize=14)

sns.barplot(data=Base_Dados, x='Plataforma', y='Vendas_Global', ci=None, color=Paleta_Cores[4], estimator=sum)

#Label
plt.ylabel('Quantidade de vendas (mi)');

# %%
#Criando um dataframe que agrupa as vendas globais por plataforma
Analise_Plataformas = Base_Dados.groupby(['Plataforma'])['Vendas_Global'].sum().reset_index()
#Organizando o dataframe análise em ordem
Analise_Plataformas.sort_values(by='Vendas_Global', ascending=False, inplace=True)
Analise_Plataformas.head()
# Out:
#    Plataforma  Vendas_Global
# 16        PS2        1233.46
# 28       X360         961.39
# 17        PS3         931.15
# 26        Wii         891.74
# 4          DS         803.73

# %%
# Plot geral do Top 5 Plataformas
plt.figure(figsize=(15, 6))
plt.title('Top 5 Plataformas com mais vendas de jogos')
plt.pie(
    Analise_Plataformas['Vendas_Global'].head(5),  #Apenas os 5 primeiros registros da coluna de vendas globais
    labels=Analise_Plataformas['Plataforma'].head(5),  #Apenas os 5 primeiros valores da coluna plataforma
    startangle=90, #Angulação da pizza
    autopct='%1.1f%%', #As porcentagens ficam dentro das fatias
);

# %%
#Criando um dataframe que agrupa as vendas globais por publicadora
Analise_Publicadoras = Base_Dados.groupby(['Publicadora'])['Vendas_Global'].sum().reset_index()
#Organizando o dataframe análise em ordem
Analise_Publicadoras.sort_values(by='Vendas_Global', ascending=False, inplace=True)
Analise_Publicadoras.reset_index(drop=True, inplace=True)
Analise_Publicadoras.head()
# Out:
#                    Publicadora  Vendas_Global
# 0                     Nintendo        1786.72
# 1              Electronic Arts        1100.05
# 2                   Activision         725.14
# 3  Sony Computer Entertainment         606.27
# 4                      Ubisoft         470.45

# %%
# Plot geral do Top 5 Publicadoras
plt.figure(figsize=(15, 6))
plt.title('Top 5 Publicadoras com mais vendas')
plt.pie(
    Analise_Publicadoras['Vendas_Global'].head(5),  #Apenas os 5 primeiros registros da coluna de vendas globais
    labels=Analise_Publicadoras['Publicadora'].head(5),  #Apenas os 5 primeiros valores da coluna plataforma
    startangle=90,
    autopct='%1.1f%%',
);

# %% [markdown]
# # Análise Nintendo

# %%
#Criando um dataframe que agrupa as vendas globais de jogos apenas da Nintendo
Analise_Nintendo = Base_Dados[Base_Dados['Publicadora'] == 'Nintendo']
Analise_Nintendo.head()
# Out:
#                        Nome Plataforma  Ano_Lancamento        Genero  \
# 0                Wii Sports        Wii          2006.0        Sports
# 1         Super Mario Bros.        NES          1985.0      Platform
# 2            Mario Kart Wii        Wii          2008.0        Racing
# 3         Wii Sports Resort        Wii          2009.0        Sports
# 4  Pokemon Red/Pokemon Blue         GB          1996.0  Role-Playing
#
#   Publicadora  Vendas_America_Norte  Vendas_Europa  Vendas_Japao  \
# 0    Nintendo                 41.36          28.96          3.77
# 1    Nintendo                 29.08           3.58          6.81
# 2    Nintendo                 15.68          12.76          3.79
# 3    Nintendo                 15.61          10.93          3.28
# 4    Nintendo                 11.27           8.89         10.22
#
#    Vendas_Outras_Regioes  Vendas_Global
# 0                   8.45          82.53
# 1                   0.77          40.24
# 2                   3.29          35.52
# 3                   2.95          32.77
# 4                   1.00          31.37

# %%
#Tamanho da Imagem
plt.figure(figsize=(15,5))

#Título
plt.title('Vendas de jogos por consoles - Nintendo', loc='left', fontsize=14)

sns.barplot(data=Analise_Nintendo, x='Plataforma', y='Vendas_Global', ci=None, color=Paleta_Cores[7], estimator=sum)

#Label
plt.xlabel('Plataforma')
plt.ylabel('Quantidade de vendas (mi)');

# %%
#Tamanho da Imagem
plt.figure(figsize=(15,5))

#Título
plt.title('Gêneros de jogos mais vendidos - Nintendo', loc='left', fontsize=14)

sns.barplot(data=Analise_Nintendo, x='Genero', y='Vendas_Global', ci=None, color=Paleta_Cores[8], estimator=sum)

#Label
plt.xlabel('Gênero')
plt.ylabel('Quantidade de vendas (mi)');

# %%
#Vendas da Nintendo por região ao longo dos anos
labels = ['América do Norte', 'Europa', 'Japão', 'Outras Regiões']
sizes = [Analise_Nintendo['Vendas_America_Norte'].sum(), Analise_Nintendo['Vendas_Europa'].sum(), Analise_Nintendo['Vendas_Japao'].sum(), Analise_Nintendo['Vendas_Outras_Regioes'].sum()]

plt.figure(figsize=(10, 6))
plt.pie(
    sizes,
    labels=labels,
    autopct='%1.1f%%',
    startangle=90,
    )
plt.title('Vendas de Jogos da Nintendo por Região ao longo dos anos', fontsize=14, weight='bold')
plt.show()

# %% [markdown]
# # Análise Geral - Vendas por Região

# %%
#Criando um dataframe que agrupa as vendas globais de jogos por região
Analise_Global = Base_Dados.groupby(['Ano_Lancamento'])[['Vendas_America_Norte', 'Vendas_Europa', 'Vendas_Japao', 'Vendas_Outras_Regioes', 'Vendas_Global']].sum()
Analise_Global.head()
# Out:
#                 Vendas_America_Norte  Vendas_Europa  Vendas_Japao  \
# Ano_Lancamento
# 1980.0                         10.59           0.67          0.00
# 1981.0                         33.40           1.96          0.00
# 1982.0                         26.92           1.65          0.00
# 1983.0                          7.76           0.80          8.10
# 1984.0                         33.28           2.10         14.27
#
#                 Vendas_Outras_Regioes  Vendas_Global
# Ano_Lancamento
# 1980.0                           0.12          11.38
# 1981.0                           0.32          35.77
# 1982.0                           0.31          28.86
# 1983.0                           0.14          16.79
# 1984.0                           0.70          50.36

# %%
#Barras do gráfico
America = Analise_Global['Vendas_America_Norte'].sum()
Europa = Analise_Global['Vendas_Europa'].sum()
Japao = Analise_Global['Vendas_Japao'].sum()
Outras_Regioes = Analise_Global['Vendas_Outras_Regioes'].sum()

Largura_Barra = 0.85
Rotulos = ['América do Norte', 'Europa', 'Japão', 'Outras Regiões']
Valores = [America, Europa, Japao, Outras_Regioes]

#Tamanho da Imagem
plt.figure(figsize=(15,5))

#Título
plt.title('Vendas Globais de jogos por Região ao longo dos anos', loc='left', fontsize=14)

#Plot da América
plt.bar(Rotulos[0], Valores[0], label=Rotulos[0], width=Largura_Barra, color='#b5ffb9', edgecolor='white')

#Plot da Europa
plt.bar(Rotulos[1], Valores[1], label=Rotulos[1], width=Largura_Barra, color='#f9bc86', edgecolor='white')

#Plot do Japão
plt.bar(Rotulos[2], Valores[2], label=Rotulos[2], width=Largura_Barra, color='#a3acff', edgecolor='white')

#Plot das Outras Regiões
plt.bar(Rotulos[3], Valores[3], label=Rotulos[3], width=Largura_Barra, color='#ffb3e6', edgecolor='white');

# %%
#Df para armazenar as vendas por publicadoras ao longo dos anos
publicadoras = ['Nintendo', 'Electronic Arts', 'Activision', 'Sony Computer Entertainment', 'Ubisoft']

# Criando um dicionário para armazenar os DataFrames processados
Dicionario_Publicadoras = {}

for publicadora in publicadoras:
    df = (Base_Dados[Base_Dados['Publicadora'] == publicadora]
          .groupby('Ano_Lancamento')['Vendas_Global']
          .sum()
          .reset_index()
          .set_index('Ano_Lancamento'))

    Dicionario_Publicadoras[publicadora] = df

# %%
#Criando gráfico de linhas com as vendas das publicadoras ao longo dos anos utilizando o dicionário criado na célula anterior

# Criando a figura e o eixo
plt.figure(figsize=(12, 6))

# Percorrendo o dicionário e plotando cada publicadora
for publicadora, df in Dicionario_Publicadoras.items():
    plt.plot(df.index, df['Vendas_Global'], label=publicadora)

# Personalizando o gráfico
plt.xlabel('Ano de Lançamento')
plt.ylabel('Vendas Globais (milhões)')
plt.title('Vendas Globais por Publicadora ao Longo dos Anos')
plt.legend()  # Adiciona legenda para diferenciar as publicadoras

# Exibir o gráfico
plt.show()

# %% [markdown]
# # Relatório final

# %%
# Tamanho da Imagem
fig, ax = plt.subplots( figsize=(18, 15) )
plt.xticks(fontsize=0) #Removendo os valores dos eixos x e y que o subplots cria por padrão, para que fiquem somente os valores dos gráficos criados abaixo
plt.yticks(fontsize=0)

# Cor de fundo
Cor_Fundo = '#f5f5f5'
ax.set_facecolor( Cor_Fundo )
fig.set_facecolor( Cor_Fundo )


# Titulo da figura
plt.suptitle('Projeto Prático \n Análise do Mercado de Games - Vendas de jogos', fontsize=22, color='#404040', fontweight=600)

# Parametros para o grid
Linhas = 3
Colunas = 2

# Acessando gráfico 1
plt.subplot(Linhas, Colunas, 1)
plt.title('Gêneros de jogos com mais vendas globalmente (1980 a 2020)', loc='left', fontsize=14)
plt.bar(Base_Dados['Genero'].astype(str).head(16), Base_Dados['Vendas_Global'].head(16), color=Paleta_Cores[0], edgecolor=Paleta_Cores[0])
plt.xlabel('Gênero')
plt.ylabel('Quantidade de vendas (mi)')
plt.grid(False)


# Acessando gráfico 2
plt.subplot(Linhas, Colunas, 2)
plt.title('Consoles com jogos mais vendidos globalmente (1980 a 2020)', loc='left', fontsize=14)
plt.bar(Base_Dados['Plataforma'].astype(str).head(20), Base_Dados['Vendas_Global'].head(20), color=Paleta_Cores[4], edgecolor=Paleta_Cores[4])
plt.xlabel('Console')
plt.ylabel('Quantidade de vendas (mi)')
plt.grid(False)


# Acessando gráfico 3
plt.subplot(Linhas, Colunas, 3)
plt.title('Top 10 Vendas de jogos por consoles - Nintendo', loc='left', fontsize=14)
sns.barplot(data=Analise_Nintendo, x='Plataforma', y='Vendas_Global', ci=None, color=Paleta_Cores[7], estimator=sum)
plt.xlabel('Plataforma')
plt.ylabel('Quantidade de vendas (mi)')
plt.grid(False)

# Acessando gráfico 4
plt.subplot(Linhas, Colunas, 4)
plt.title('Top 8 Gêneros de jogos mais vendidos - Nintendo', loc='left', fontsize=14)
plt.bar(Analise_Nintendo['Genero'].astype(str).head(20), Analise_Nintendo['Vendas_Global'].head(20), color=Paleta_Cores[8], edgecolor=Paleta_Cores[8])
plt.xlabel('Gênero')
plt.ylabel('Quantidade de vendas (mi)')
plt.grid(False)


# Acessando gráfico 5
plt.subplot(Linhas, Colunas, 5)
plt.title('Vendas Globais de jogos por Região (1980 a 2020)', loc='left', fontsize=14)
plt.bar(Rotulos[0], Valores[0], label=Rotulos[0], width=Largura_Barra, color='#b5ffb9')
plt.bar(Rotulos[1], Valores[1], label=Rotulos[1], width=Largura_Barra, color='#f9bc86')
plt.bar(Rotulos[2], Valores[2], label=Rotulos[2], width=Largura_Barra, color='#a3acff')
plt.bar(Rotulos[3], Valores[3], label=Rotulos[3], width=Largura_Barra, color='#ffb3e6')
plt.xlabel('Região')
plt.ylabel('Quantidade de vendas (mi)')
plt.grid(False)


# Acessando gráfico 6
plt.subplot(Linhas, Colunas, 6)
for publicadora, df in Dicionario_Publicadoras.items():
    plt.plot(df.index, df['Vendas_Global'], label=publicadora)
plt.xlabel('Ano de Lançamento')
plt.ylabel('Quantidade de vendas (mi)')
plt.title('Vendas Globais por Publicadora (1980 a 2020)', loc='left', fontsize=14)
plt.legend()
plt.grid(False)


# Ajustar o layout
plt.subplots_adjust( hspace=0.4, wspace=0.3 )

#Rodapé
Rodape = '''
Esse relatório foi elaborado por Jeferson da Silva Carmo
@jefersoncarmoo
'''

# Incluindo o rodape no relatorio
fig.text( 0.5, -0.02, Rodape, ha='center', va='bottom', size=12, color='#938ca1');
